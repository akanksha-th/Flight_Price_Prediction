# %%
from selenium import webdriver
from time import sleep

# Set up the WebDriver (make sure you have the appropriate driver installed)
driver = webdriver.Chrome()

# Open Google Flights
driver.get("https://www.google.com/flights")

# Wait for the page to load
sleep(5)

# Extract flight data (example: flight names and prices)
flight_data = driver.find_element_by_xpath("xpath_to_targeted_data").text
print(flight_data)

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 14
#      11 sleep(5)
#      13 # Extract flight data (example: flight names and prices)
# ---> 14 flight_data = driver.find_element_by_xpath("xpath_to_targeted_data").text
#      15 print(flight_data)
#      17 driver.quit()
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_xpath'

# %%
import pandas as pd

df = pd.DataFrame(flight_data)

# Save data as CSV
df.to_csv('flights.csv', index=False)
